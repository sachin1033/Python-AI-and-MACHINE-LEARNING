# %%
import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img=Image.open('sample.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x221121DC760>

# %%
text=pytesseract.image_to_string(img)
print(text)
# Out:
#
#
# Le sport est bon pour nos études !
#
# reux éléves arrétent de faire du sport er
# . Ils sont trop occupés par leurs études
# oirs. Pour beaucoup, c’est un sacrifice «
# sport mais ils pensent qu’il est impossi
# sport et réussite scolaire. Pourtant de
#
# x pédagogues, psychologues et médecir
# aue le enart améliore convent lec récn]
