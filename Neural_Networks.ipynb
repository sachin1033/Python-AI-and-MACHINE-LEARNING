# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin1033/Python-AI-and-MACHINE-LEARNING/blob/main/Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-aec6e8fa-7377-495a-8368-fea8f5277bab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aec6e8fa-7377-495a-8368-fea8f5277bab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes (1).csv to diabetes (1).csv

# %%
import pandas as pd
df=pd.read_csv("diabetes (1).csv")

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
x=df.iloc[:,0:8]
y=df.iloc[:,-1]

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
seed=7
np.random.seed(seed)

# %%
#create model
model=Sequential()
model.add(Dense(12,input_dim=8,kernel_initializer='uniform',activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
#compile the model
model.compile(loss='binary_crossentropy',optimizer='adam',metrics='accuracy')

# %%
#fit the model
model.fit(x,y,epochs=500,batch_size=10)
# Out:
# Epoch 1/500
# 77/77 [==============================] - 1s 1ms/step - loss: 0.7915 - accuracy: 0.6060
# Epoch 2/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6762 - accuracy: 0.6158
# Epoch 3/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6305 - accuracy: 0.6778
# Epoch 4/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6237 - accuracy: 0.6652
# Epoch 5/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5952 - accuracy: 0.6924
# Epoch 6/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6279 - accuracy: 0.6515
# Epoch 7/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5987 - accuracy: 0.6809
# Epoch 8/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5905 - accuracy: 0.7034
# Epoch 9/500
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5870 - accuracy: 0.6956
# Epoch 10/500
# ...

# %%
scores=model.evaluate(x,y)
print("%s:%2%",(model.metrics_names[1],scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.7982
# %s:%2% ('accuracy', 79.81770634651184)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=seed)

# %%
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=150, batch_size=10)

# %%
# define 10-fold cross validation test harness
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
for train, test in kfold.split(x, y):
# create model
  scores = model.evaluate(x_test, y_test, verbose=0)
  print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
  cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# accuracy: 83.12%
# 83.12% (+/- 0.00%)
